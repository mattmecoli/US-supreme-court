# %%
import numpy as np
import pandas as pd

# %%
raw_jc = pd.read_csv("SCDB_2018_01_justiceCentered_Citation.csv", encoding = "ISO-8859-1")

# %%
raw_jc.head()
# Out:
#      caseId     docketId    caseIssuesId                voteId dateDecision  \
# 0  1946-001  1946-001-01  1946-001-01-01  1946-001-01-01-01-01   11/18/1946
# 1  1946-001  1946-001-01  1946-001-01-01  1946-001-01-01-01-02   11/18/1946
# 2  1946-001  1946-001-01  1946-001-01-01  1946-001-01-01-01-03   11/18/1946
# 3  1946-001  1946-001-01  1946-001-01-01  1946-001-01-01-01-04   11/18/1946
# 4  1946-001  1946-001-01  1946-001-01-01  1946-001-01-01-01-05   11/18/1946
#
#    decisionType      usCite      sctCite      ledCite             lexisCite  \
# 0             1  329 U.S. 1  67 S. Ct. 6  91 L. Ed. 3  1946 U.S. LEXIS 1724
# 1             1  329 U.S. 1  67 S. Ct. 6  91 L. Ed. 3  1946 U.S. LEXIS 1724
# 2             1  329 U.S. 1  67 S. Ct. 6  91 L. Ed. 3  1946 U.S. LEXIS 1724
# 3             1  329 U.S. 1  67 S. Ct. 6  91 L. Ed. 3  1946 U.S. LEXIS 1724
# 4             1  329 U.S. 1  67 S. Ct. 6  91 L. Ed. 3  1946 U.S. LEXIS 1724
#
# ...

# %%
RBG_df = raw_jc[raw_jc['justiceName'] == 'RBGinsburg']

# %%
RBG_df.shape
# Out:
# (2092, 61)

# %%
#RBG_df['lcDisposition'] = RBG_df['adminAction'].apply(lambda x: 4 if pd.notna(x) else x)

# %%
RBG_df.lcDisposition
# Out:
# 60889     NaN
# 60898     NaN
# 60907     2.0
# 60916     2.0
# 60925     6.0
# 60934     4.0
# 60943     7.0
# 60952     4.0
# 60961     2.0
# 60970     NaN
# 60979     2.0
# 60988     2.0
# 60997     2.0
# 61006     5.0
# 61015     2.0
# 61024     2.0
# 61033     2.0
# 61042     2.0
# 61051     3.0
# 61060     2.0
# 61069     3.0
# 61078     3.0
# 61087     3.0
# 61096     2.0
# 61105     2.0
# 61114     2.0
# 61123     2.0
# 61132     2.0
# 61141     4.0
# 61150     2.0
#          ...
# 79345     2.0
# 79354     9.0
# 79363     NaN
# 79372    12.0
# 79381     2.0
# 79390     NaN
# 79399     3.0
# 79408     2.0
# 79417     6.0
# 79426     2.0
# 79435     3.0
# 79444     2.0
# 79453     2.0
# 79462     3.0
# 79471     2.0
# 79480    12.0
# 79489     3.0
# 79498     2.0
# 79507     2.0
# 79516     9.0
# 79525     9.0
# 79534     2.0
# 79543     NaN
# 79552     3.0
# 79561     4.0
# 79570     2.0
# 79579     5.0
# 79588     NaN
# 79597     2.0
# 79606     3.0
# ...

# %%
RBG_df = RBG_df.fillna(999)

# %%
RBG_df.head()
# Out:
#          caseId     docketId    caseIssuesId                voteId  \
# 60889  1993-001  1993-001-01  1993-001-01-01  1993-001-01-01-01-09
# 60898  1993-002  1993-002-01  1993-002-01-01  1993-002-01-01-01-09
# 60907  1993-003  1993-003-01  1993-003-01-01  1993-003-01-01-01-09
# 60916  1993-004  1993-004-01  1993-004-01-01  1993-004-01-01-01-09
# 60925  1993-005  1993-005-01  1993-005-01-01  1993-005-01-01-01-09
#
#       dateDecision  decisionType       usCite         sctCite  \
# 60889   10/12/1993             2   510 U.S. 1    114 S. Ct. 4
# 60898   10/12/1993             2   510 U.S. 4    114 S. Ct. 2
# 60907    11/9/1993             1   510 U.S. 7  114 S. Ct. 361
# 60916    11/9/1993             1  510 U.S. 17  114 S. Ct. 367
# 60925   11/30/1993             6  510 U.S. 27  114 S. Ct. 425
#
#                  ledCite             lexisCite       ...         majVotes  \
# 60889    126 L. Ed. 2d 1  1993 U.S. LEXIS 6308       ...                9
# ...
